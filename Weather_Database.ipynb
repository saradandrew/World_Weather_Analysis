# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d89f5c8bf308c56dd1cfc5f31523357

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_list = city_weather["weather"]
        weather = weather_list[0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | hami
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | sainte-maxime
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | gisborne
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | tonj
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | tabuk
# Processing Record 16 of Set 1 | christchurch
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | cayenne
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 1 | plover
# Processing Record 22 of Set 1 | zyryanka
# Processing Record 23 of Set 1 | borogontsy
# Processing Record 24 of Set 1 | san quintin
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | meulaboh
# Processing Record 27 of Set 1 | oranjestad
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | prosotsani
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | nabire
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | fortuna
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | belen
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | xuanhua
# Processing Record 44 of Set 1 | antalaha
# Processing Record 45 of Set 1 | shadegan
# Processing Record 46 of Set 1 | karatau
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | arkhangelsk
# Processing Record 3 of Set 2 | comodoro rivadavia
# Processing Record 4 of Set 2 | pochutla
# Processing Record 5 of Set 2 | bontang
# Processing Record 6 of Set 2 | hit
# Processing Record 7 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 2 | chuy
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | san patricio
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | great falls
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | yopal
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | bagotville
# Processing Record 25 of Set 2 | linguere
# Processing Record 26 of Set 2 | pangnirtung
# Processing Record 27 of Set 2 | naze
# Processing Record 28 of Set 2 | avera
# Processing Record 29 of Set 2 | cassilandia
# Processing Record 30 of Set 2 | itoman
# Processing Record 31 of Set 2 | pandan
# Processing Record 32 of Set 2 | sakakah
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | san carlos
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 2 | lagoa
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | pershotravneve
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | buta
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | la ronge
# Processing Record 49 of Set 2 | haines junction
# Processing Record 50 of Set 2 | tunceli
# Processing Record 1 of Set 3 | portland
# Processing Record 2 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | ushumun
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | egvekinot
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | puerto carreno
# Processing Record 11 of Set 3 | bandarbeyla
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | saquarema
# Processing Record 14 of Set 3 | black river
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | mizan teferi
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | kuruman
# Processing Record 19 of Set 3 | toropets
# Processing Record 20 of Set 3 | manama
# Processing Record 21 of Set 3 | yanji
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | norman wells
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | shimoda
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | katangli
# Processing Record 28 of Set 3 | sabaudia
# Processing Record 29 of Set 3 | rio tercero
# Processing Record 30 of Set 3 | mareeba
# Processing Record 31 of Set 3 | hazorasp
# Processing Record 32 of Set 3 | vredendal
# Processing Record 33 of Set 3 | kedrovyy
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | westport
# Processing Record 36 of Set 3 | jinchang
# Processing Record 37 of Set 3 | west bay
# Processing Record 38 of Set 3 | alofi
# Processing Record 39 of Set 3 | rocha
# Processing Record 40 of Set 3 | perevolotskiy
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | gat
# Processing Record 44 of Set 3 | port hardy
# Processing Record 45 of Set 3 | klaksvik
# Processing Record 46 of Set 3 | yulara
# Processing Record 47 of Set 3 | vilcun
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | torbay
# Processing Record 1 of Set 4 | clyde
# Processing Record 2 of Set 4 | carauari
# Processing Record 3 of Set 4 | sibolga
# Processing Record 4 of Set 4 | novovarshavka
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | san carlos de bariloche
# Processing Record 8 of Set 4 | gotsu
# Processing Record 9 of Set 4 | zhigansk
# Processing Record 10 of Set 4 | puerto escondido
# Processing Record 11 of Set 4 | sandwick
# Processing Record 12 of Set 4 | arman
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | lazarev
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | namibe
# Processing Record 17 of Set 4 | buin
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | hualmay
# Processing Record 20 of Set 4 | kangaatsiaq
# Processing Record 21 of Set 4 | bilma
# Processing Record 22 of Set 4 | tilichiki
# Processing Record 23 of Set 4 | buriti
# Processing Record 24 of Set 4 | shiyan
# Processing Record 25 of Set 4 | swinoujscie
# Processing Record 26 of Set 4 | ouegoa
# Processing Record 27 of Set 4 | kawalu
# Processing Record 28 of Set 4 | sibu
# Processing Record 29 of Set 4 | port-cartier
# Processing Record 30 of Set 4 | balikpapan
# Processing Record 31 of Set 4 | varzelandia
# Processing Record 32 of Set 4 | beihai
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | mahibadhoo
# Processing Record 35 of Set 4 | boyolangu
# Processing Record 36 of Set 4 | ballina
# Processing Record 37 of Set 4 | burkburnett
# Processing Record 38 of Set 4 | deniliquin
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | khandyga
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 4 | thompson
# Processing Record 44 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 4 | del rio
# Processing Record 46 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 4 | along
# Processing Record 48 of Set 4 | atar
# Processing Record 49 of Set 4 | bonnyville
# Processing Record 50 of Set 4 | kainantu
# Processing Record 1 of Set 5 | general roca
# Processing Record 2 of Set 5 | gribanovskiy
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5 | anloga
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | vyshkov
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | nishihara
# Processing Record 9 of Set 5 | sokolo
# Processing Record 10 of Set 5 | wajima
# Processing Record 11 of Set 5 | villamontes
# Processing Record 12 of Set 5 | stralsund
# Processing Record 13 of Set 5 | linjiang
# Processing Record 14 of Set 5 | binghamton
# Processing Record 15 of Set 5 | srivardhan
# Processing Record 16 of Set 5 | oga
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | moron
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 5 | valday
# Processing Record 21 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 5 | alta floresta
# Processing Record 24 of Set 5 | tuktoyaktuk
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | diu
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | porosozero
# Processing Record 30 of Set 5 | anadyr
# Processing Record 31 of Set 5 | hovd
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | amberley
# Processing Record 34 of Set 5 | cortez
# Processing Record 35 of Set 5 | kenai
# Processing Record 36 of Set 5 | mastic beach
# Processing Record 37 of Set 5 | flagstaff
# Processing Record 38 of Set 5 | los llanos de aridane
# Processing Record 39 of Set 5 | loandjili
# Processing Record 40 of Set 5 | aswan
# Processing Record 41 of Set 5 | port moresby
# Processing Record 42 of Set 5 | port macquarie
# Processing Record 43 of Set 5 | cantaura
# Processing Record 44 of Set 5 | mehamn
# Processing Record 45 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | miraflores
# Processing Record 47 of Set 5 | kattivakkam
# Processing Record 48 of Set 5 | gympie
# Processing Record 49 of Set 5 | falaleu
# City not found. Skipping...
# Processing Record 50 of Set 5 | sisimiut
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | fort nelson
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 6 | redlands
# Processing Record 6 of Set 6 | gushikawa
# Processing Record 7 of Set 6 | serenje
# Processing Record 8 of Set 6 | axim
# Processing Record 9 of Set 6 | brae
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | quatre cocos
# Processing Record 12 of Set 6 | billings
# Processing Record 13 of Set 6 | lompoc
# Processing Record 14 of Set 6 | emerald
# Processing Record 15 of Set 6 | krasnoselkup
# Processing Record 16 of Set 6 | narsaq
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | lasa
# Processing Record 19 of Set 6 | vestmannaeyjar
# Processing Record 20 of Set 6 | kaitangata
# Processing Record 21 of Set 6 | muzhi
# Processing Record 22 of Set 6 | dongsheng
# Processing Record 23 of Set 6 | terney
# Processing Record 24 of Set 6 | tooele
# Processing Record 25 of Set 6 | vanimo
# Processing Record 26 of Set 6 | csemo
# Processing Record 27 of Set 6 | ambilobe
# Processing Record 28 of Set 6 | tagusao
# Processing Record 29 of Set 6 | garowe
# Processing Record 30 of Set 6 | berlevag
# Processing Record 31 of Set 6 | kamenka
# Processing Record 32 of Set 6 | luanda
# Processing Record 33 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 6 | pangody
# Processing Record 35 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | kailua
# Processing Record 37 of Set 6 | goba
# Processing Record 38 of Set 6 | dubti
# Processing Record 39 of Set 6 | lerwick
# Processing Record 40 of Set 6 | batagay-alyta
# Processing Record 41 of Set 6 | leningradskiy
# Processing Record 42 of Set 6 | grand gaube
# Processing Record 43 of Set 6 | port lincoln
# Processing Record 44 of Set 6 | kununurra
# Processing Record 45 of Set 6 | waipawa
# Processing Record 46 of Set 6 | zharkent
# Processing Record 47 of Set 6 | beringovskiy
# Processing Record 48 of Set 6 | kostino
# Processing Record 49 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 50 of Set 6 | centralia
# Processing Record 1 of Set 7 | russell
# Processing Record 2 of Set 7 | faanui
# Processing Record 3 of Set 7 | alyangula
# Processing Record 4 of Set 7 | najran
# Processing Record 5 of Set 7 | marau
# Processing Record 6 of Set 7 | bonthe
# Processing Record 7 of Set 7 | vilyuysk
# Processing Record 8 of Set 7 | wadi musa
# Processing Record 9 of Set 7 | male
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | caborca
# Processing Record 13 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 7 | srandakan
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | marzuq
# Processing Record 17 of Set 7 | luorong
# Processing Record 18 of Set 7 | komsomolskiy
# Processing Record 19 of Set 7 | severo-yeniseyskiy
# Processing Record 20 of Set 7 | kota kinabalu
# Processing Record 21 of Set 7 | raudeberg
# Processing Record 22 of Set 7 | sarkand
# Processing Record 23 of Set 7 | dunedin
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | costinesti
# Processing Record 26 of Set 7 | sola
# Processing Record 27 of Set 7 | vao
# Processing Record 28 of Set 7 | talnakh
# Processing Record 29 of Set 7 | gao
# Processing Record 30 of Set 7 | tyret pervaya
# Processing Record 31 of Set 7 | recodo
# Processing Record 32 of Set 7 | the pas
# Processing Record 33 of Set 7 | adeje
# Processing Record 34 of Set 7 | key west
# Processing Record 35 of Set 7 | dayong
# Processing Record 36 of Set 7 | borovskoy
# Processing Record 37 of Set 7 | ocampo
# Processing Record 38 of Set 7 | kjollefjord
# Processing Record 39 of Set 7 | atamanovka
# Processing Record 40 of Set 7 | katherine
# Processing Record 41 of Set 7 | wladyslawowo
# Processing Record 42 of Set 7 | nizhneivkino
# Processing Record 43 of Set 7 | san matias
# Processing Record 44 of Set 7 | luena
# Processing Record 45 of Set 7 | vila franca do campo
# Processing Record 46 of Set 7 | coahuayana
# Processing Record 47 of Set 7 | hamirpur
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | pimenta bueno
# Processing Record 50 of Set 7 | mtwango
# Processing Record 1 of Set 8 | honiara
# Processing Record 2 of Set 8 | ormara
# Processing Record 3 of Set 8 | catia la mar
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | wa
# City not found. Skipping...
# Processing Record 6 of Set 8 | santa maria
# Processing Record 7 of Set 8 | yarim
# Processing Record 8 of Set 8 | thinadhoo
# Processing Record 9 of Set 8 | severo-kurilsk
# Processing Record 10 of Set 8 | banda aceh
# Processing Record 11 of Set 8 | seoul
# Processing Record 12 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 8 | cap-aux-meules
# Processing Record 14 of Set 8 | clyde river
# Processing Record 15 of Set 8 | pahrump
# Processing Record 16 of Set 8 | ciudad bolivar
# Processing Record 17 of Set 8 | shelburne
# Processing Record 18 of Set 8 | ca mau
# Processing Record 19 of Set 8 | verkhoyansk
# Processing Record 20 of Set 8 | ust-ishim
# Processing Record 21 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 8 | champerico
# Processing Record 23 of Set 8 | nagato
# Processing Record 24 of Set 8 | alice springs
# Processing Record 25 of Set 8 | mayumba
# Processing Record 26 of Set 8 | ivanivka
# Processing Record 27 of Set 8 | vyazemskiy
# Processing Record 28 of Set 8 | adrar
# Processing Record 29 of Set 8 | carlagan
# Processing Record 30 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 8 | boca do acre
# Processing Record 32 of Set 8 | puri
# Processing Record 33 of Set 8 | kulu
# Processing Record 34 of Set 8 | siguiri
# Processing Record 35 of Set 8 | barabinsk
# Processing Record 36 of Set 8 | maravilha
# Processing Record 37 of Set 8 | saint-pierre
# Processing Record 38 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 8 | korla
# Processing Record 40 of Set 8 | montale
# Processing Record 41 of Set 8 | hurghada
# Processing Record 42 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 8 | akyab
# Processing Record 44 of Set 8 | murray
# Processing Record 45 of Set 8 | sampit
# Processing Record 46 of Set 8 | guasdualito
# Processing Record 47 of Set 8 | zatyshshya
# Processing Record 48 of Set 8 | loukhi
# Processing Record 49 of Set 8 | kapuskasing
# Processing Record 50 of Set 8 | puerto colombia
# Processing Record 1 of Set 9 | qaqortoq
# Processing Record 2 of Set 9 | kushima
# Processing Record 3 of Set 9 | adelaide
# Processing Record 4 of Set 9 | lumeje
# Processing Record 5 of Set 9 | bojnurd
# Processing Record 6 of Set 9 | mariental
# Processing Record 7 of Set 9 | byron bay
# Processing Record 8 of Set 9 | goderich
# Processing Record 9 of Set 9 | nelson bay
# Processing Record 10 of Set 9 | seguela
# Processing Record 11 of Set 9 | yatou
# Processing Record 12 of Set 9 | moree
# Processing Record 13 of Set 9 | puerto leguizamo
# Processing Record 14 of Set 9 | evanston
# Processing Record 15 of Set 9 | srisailam
# Processing Record 16 of Set 9 | youghal
# Processing Record 17 of Set 9 | cua
# Processing Record 18 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 9 | sao joao da barra
# Processing Record 20 of Set 9 | dzhebariki-khaya
# Processing Record 21 of Set 9 | ierapetra
# Processing Record 22 of Set 9 | laje
# Processing Record 23 of Set 9 | mount gambier
# Processing Record 24 of Set 9 | inuvik
# Processing Record 25 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | alpena
# Processing Record 28 of Set 9 | okhotsk
# Processing Record 29 of Set 9 | karratha
# Processing Record 30 of Set 9 | moroni
# Processing Record 31 of Set 9 | isangel
# Processing Record 32 of Set 9 | mildura
# Processing Record 33 of Set 9 | bambous virieux
# Processing Record 34 of Set 9 | timra
# Processing Record 35 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 9 | neuruppin
# Processing Record 37 of Set 9 | flinders
# Processing Record 38 of Set 9 | miles city
# Processing Record 39 of Set 9 | balkhash
# Processing Record 40 of Set 9 | yangjiang
# Processing Record 41 of Set 9 | vitina
# Processing Record 42 of Set 9 | toungoo
# City not found. Skipping...
# Processing Record 43 of Set 9 | kibala
# Processing Record 44 of Set 9 | ippy
# Processing Record 45 of Set 9 | dwarka
# Processing Record 46 of Set 9 | wuwei
# Processing Record 47 of Set 9 | mandan
# Processing Record 48 of Set 9 | novikovo
# Processing Record 49 of Set 9 | saint-augustin
# Processing Record 50 of Set 9 | knysna
# Processing Record 1 of Set 10 | tornio
# Processing Record 2 of Set 10 | paamiut
# Processing Record 3 of Set 10 | iroquois falls
# Processing Record 4 of Set 10 | samarai
# Processing Record 5 of Set 10 | kon tum
# Processing Record 6 of Set 10 | mahajanga
# Processing Record 7 of Set 10 | kaeng khoi
# Processing Record 8 of Set 10 | tyn nad vltavou
# Processing Record 9 of Set 10 | port keats
# Processing Record 10 of Set 10 | kuleshovka
# Processing Record 11 of Set 10 | patnongon
# Processing Record 12 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 13 of Set 10 | ryotsu
# Processing Record 14 of Set 10 | liyang
# Processing Record 15 of Set 10 | cabedelo
# Processing Record 16 of Set 10 | nizhniy ingash
# Processing Record 17 of Set 10 | bambanglipuro
# Processing Record 18 of Set 10 | nurota
# Processing Record 19 of Set 10 | glossop
# Processing Record 20 of Set 10 | victor harbor
# Processing Record 21 of Set 10 | aklavik
# Processing Record 22 of Set 10 | port blair
# Processing Record 23 of Set 10 | oranjemund
# Processing Record 24 of Set 10 | puerto padre
# Processing Record 25 of Set 10 | baruun-urt
# Processing Record 26 of Set 10 | konotop
# Processing Record 27 of Set 10 | roxana
# Processing Record 28 of Set 10 | jasper
# Processing Record 29 of Set 10 | filadelfia
# Processing Record 30 of Set 10 | bustamante
# Processing Record 31 of Set 10 | sabha
# Processing Record 32 of Set 10 | lavrentiya
# Processing Record 33 of Set 10 | chicama
# Processing Record 34 of Set 10 | asau
# Processing Record 35 of Set 10 | talara
# Processing Record 36 of Set 10 | namatanai
# Processing Record 37 of Set 10 | college
# Processing Record 38 of Set 10 | zverinogolovskoye
# Processing Record 39 of Set 10 | kinshasa
# Processing Record 40 of Set 10 | dingle
# Processing Record 41 of Set 10 | nachalovo
# Processing Record 42 of Set 10 | verkh-chebula
# Processing Record 43 of Set 10 | ilulissat
# Processing Record 44 of Set 10 | laguna
# Processing Record 45 of Set 10 | zakamensk
# Processing Record 46 of Set 10 | fort-shevchenko
# Processing Record 47 of Set 10 | morant bay
# Processing Record 48 of Set 10 | kuah
# Processing Record 49 of Set 10 | ratnagiri
# Processing Record 50 of Set 10 | uchiza
# Processing Record 1 of Set 11 | tommot
# Processing Record 2 of Set 11 | ambulu
# Processing Record 3 of Set 11 | newport
# Processing Record 4 of Set 11 | kashi
# Processing Record 5 of Set 11 | tena
# Processing Record 6 of Set 11 | baykit
# Processing Record 7 of Set 11 | arroio grande
# Processing Record 8 of Set 11 | saint george
# Processing Record 9 of Set 11 | vaitape
# Processing Record 10 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 11 | ambunti
# Processing Record 13 of Set 11 | evensk
# Processing Record 14 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 11 | ayia marina
# Processing Record 16 of Set 11 | miguel hidalgo
# Processing Record 17 of Set 11 | abaza
# Processing Record 18 of Set 11 | laiyang
# Processing Record 19 of Set 11 | de-kastri
# Processing Record 20 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | kilindoni
# Processing Record 23 of Set 11 | geraldton
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | bartica
# Processing Record 26 of Set 11 | ranfurly
# Processing Record 27 of Set 11 | tessalit
# Processing Record 28 of Set 11 | kudahuvadhoo
# Processing Record 29 of Set 11 | thanatpin
# Processing Record 30 of Set 11 | bintulu
# Processing Record 31 of Set 11 | ranau
# Processing Record 32 of Set 11 | salekhard
# Processing Record 33 of Set 11 | rio gallegos
# Processing Record 34 of Set 11 | callaway
# Processing Record 35 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 36 of Set 11 | cordoba
# Processing Record 37 of Set 11 | broken hill
# Processing Record 38 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 39 of Set 11 | necochea
# Processing Record 40 of Set 11 | micheweni
# Processing Record 41 of Set 11 | juneau
# Processing Record 42 of Set 11 | dedza
# Processing Record 43 of Set 11 | boende
# Processing Record 44 of Set 11 | panguna
# Processing Record 45 of Set 11 | paka
# Processing Record 46 of Set 11 | leshukonskoye
# Processing Record 47 of Set 11 | hongan
# City not found. Skipping...
# Processing Record 48 of Set 11 | prado
# Processing Record 49 of Set 11 | kuusamo
# Processing Record 50 of Set 11 | wanning
# Processing Record 1 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 3 of Set 12 | alappuzha
# Processing Record 4 of Set 12 | morros
# Processing Record 5 of Set 12 | tolentino
# Processing Record 6 of Set 12 | phalaborwa
# Processing Record 7 of Set 12 | dohar
# Processing Record 8 of Set 12 | grindavik
# Processing Record 9 of Set 12 | jazzin
# City not found. Skipping...
# Processing Record 10 of Set 12 | juegang
# Processing Record 11 of Set 12 | bhum
# Processing Record 12 of Set 12 | salto
# Processing Record 13 of Set 12 | uaua
# Processing Record 14 of Set 12 | papara
# Processing Record 15 of Set 12 | faya
# Processing Record 16 of Set 12 | igrim
# Processing Record 17 of Set 12 | ahipara
# Processing Record 18 of Set 12 | japura
# Processing Record 19 of Set 12 | salalah
# Processing Record 20 of Set 12 | astana
# Processing Record 21 of Set 12 | kiruna
# Processing Record 22 of Set 12 | nouadhibou
# Processing Record 23 of Set 12 | glowno
# Processing Record 24 of Set 12 | praia
# Processing Record 25 of Set 12 | barra do corda
# Processing Record 26 of Set 12 | kismayo
# Processing Record 27 of Set 12 | voyinka
# Processing Record 28 of Set 12 | kandiari
# Processing Record 29 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 12 | bud
# Processing Record 31 of Set 12 | derzhavinsk
# Processing Record 32 of Set 12 | kahului
# Processing Record 33 of Set 12 | waingapu
# Processing Record 34 of Set 12 | road town
# Processing Record 35 of Set 12 | bulgan
# Processing Record 36 of Set 12 | barra do garcas
# Processing Record 37 of Set 12 | manadhoo
# Processing Record 38 of Set 12 | eisenberg
# Processing Record 39 of Set 12 | baoding
# Processing Record 40 of Set 12 | highland park
# Processing Record 41 of Set 12 | yerbabuena
# Processing Record 42 of Set 12 | rawson
# Processing Record 43 of Set 12 | chapais
# Processing Record 44 of Set 12 | ostrovnoy
# Processing Record 45 of Set 12 | saryozek
# Processing Record 46 of Set 12 | tual
# Processing Record 47 of Set 12 | gewane
# Processing Record 48 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 12 | ahuimanu
# Processing Record 50 of Set 12 | talakan
# Processing Record 1 of Set 13 | shenzhen
# Processing Record 2 of Set 13 | olivenza
# Processing Record 3 of Set 13 | hofn
# Processing Record 4 of Set 13 | garoua
# Processing Record 5 of Set 13 | mpulungu
# Processing Record 6 of Set 13 | mangan
# Processing Record 7 of Set 13 | ust-tarka
# Processing Record 8 of Set 13 | harper
# Processing Record 9 of Set 13 | pindi gheb
# Processing Record 10 of Set 13 | ellsworth
# Processing Record 11 of Set 13 | dekar
# Processing Record 12 of Set 13 | manggar
# Processing Record 13 of Set 13 | the valley
# Processing Record 14 of Set 13 | paita
# Processing Record 15 of Set 13 | canyon
# Processing Record 16 of Set 13 | iranshahr
# Processing Record 17 of Set 13 | hambantota
# Processing Record 18 of Set 13 | yeppoon
# Processing Record 19 of Set 13 | pittsfield
# Processing Record 20 of Set 13 | sogne
# Processing Record 21 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 13 | hryshkivtsi
# Processing Record 23 of Set 13 | progreso
# Processing Record 24 of Set 13 | camacha
# Processing Record 25 of Set 13 | indramayu
# Processing Record 26 of Set 13 | chunskiy
# Processing Record 27 of Set 13 | benghazi
# Processing Record 28 of Set 13 | fare
# Processing Record 29 of Set 13 | leninskoye
# Processing Record 30 of Set 13 | shenjiamen
# Processing Record 31 of Set 13 | siena
# Processing Record 32 of Set 13 | balas
# Processing Record 33 of Set 13 | tautira
# Processing Record 34 of Set 13 | kuching
# Processing Record 35 of Set 13 | acajutla
# Processing Record 36 of Set 13 | tocopilla
# Processing Record 37 of Set 13 | campo bom
# Processing Record 38 of Set 13 | barcelos
# Processing Record 39 of Set 13 | kibray
# Processing Record 40 of Set 13 | nenjiang
# Processing Record 41 of Set 13 | airai
# Processing Record 42 of Set 13 | basco
# Processing Record 43 of Set 13 | berdigestyakh
# Processing Record 44 of Set 13 | aktash
# Processing Record 45 of Set 13 | shepsi
# Processing Record 46 of Set 13 | kaseda
# Processing Record 47 of Set 13 | saint anthony
# Processing Record 48 of Set 13 | san vicente
# Processing Record 49 of Set 13 | obidos
# Processing Record 50 of Set 13 | nizwa
# Processing Record 1 of Set 14 | lima
# Processing Record 2 of Set 14 | swift current
# Processing Record 3 of Set 14 | sur
# Processing Record 4 of Set 14 | kisangani
# Processing Record 5 of Set 14 | manitouwadge
# Processing Record 6 of Set 14 | kuybysheve
# Processing Record 7 of Set 14 | santa ines
# Processing Record 8 of Set 14 | kambove
# Processing Record 9 of Set 14 | mega
# Processing Record 10 of Set 14 | touros
# Processing Record 11 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 14 | chumikan
# Processing Record 13 of Set 14 | sturgeon bay
# Processing Record 14 of Set 14 | tambura
# Processing Record 15 of Set 14 | manokwari
# Processing Record 16 of Set 14 | yuli
# Processing Record 17 of Set 14 | umea
# Processing Record 18 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 19 of Set 14 | krasnousolskiy
# City not found. Skipping...
# Processing Record 20 of Set 14 | teguldet
# Processing Record 21 of Set 14 | independence
# Processing Record 22 of Set 14 | nuevo laredo
# Processing Record 23 of Set 14 | upington
# Processing Record 24 of Set 14 | saint-louis
# Processing Record 25 of Set 14 | camopi
# Processing Record 26 of Set 14 | marsa matruh
# Processing Record 27 of Set 14 | karlshamn
# Processing Record 28 of Set 14 | sulangan
# Processing Record 29 of Set 14 | andenes
# Processing Record 30 of Set 14 | sorland
# Processing Record 31 of Set 14 | soyo
# Processing Record 32 of Set 14 | gaoual
# Processing Record 33 of Set 14 | fairview
# Processing Record 34 of Set 14 | timmins
# Processing Record 35 of Set 14 | srednekolymsk
# Processing Record 36 of Set 14 | baherden
# Processing Record 37 of Set 14 | cuauhtemoc
# Processing Record 38 of Set 14 | abha
# Processing Record 39 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 14 | mitsamiouli
# Processing Record 41 of Set 14 | lata
# Processing Record 42 of Set 14 | luba
# Processing Record 43 of Set 14 | churapcha
# Processing Record 44 of Set 14 | san juan
# Processing Record 45 of Set 14 | mandera
# Processing Record 46 of Set 14 | sikasso
# Processing Record 47 of Set 14 | burnie
# Processing Record 48 of Set 14 | nalut
# Processing Record 49 of Set 14 | rjukan
# Processing Record 50 of Set 14 | anamur
# Processing Record 1 of Set 15 | santa rosa de aguan
# Processing Record 2 of Set 15 | zapolyarnyy
# Processing Record 3 of Set 15 | anan
# Processing Record 4 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 15 | povorino
# Processing Record 6 of Set 15 | lesnoye
# Processing Record 7 of Set 15 | dhidhdhoo
# Processing Record 8 of Set 15 | innisfail
# Processing Record 9 of Set 15 | half moon bay
# Processing Record 10 of Set 15 | walvis bay
# Processing Record 11 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 15 | poum
# Processing Record 13 of Set 15 | adana
# Processing Record 14 of Set 15 | sao goncalo do amarante
# Processing Record 15 of Set 15 | terra roxa
# Processing Record 16 of Set 15 | harqalah
# Processing Record 17 of Set 15 | vysokogornyy
# Processing Record 18 of Set 15 | bolivar
# Processing Record 19 of Set 15 | samfya
# Processing Record 20 of Set 15 | kuybyshevo
# Processing Record 21 of Set 15 | mayna
# Processing Record 22 of Set 15 | kemijarvi
# Processing Record 23 of Set 15 | acari
# Processing Record 24 of Set 15 | nsunga
# Processing Record 25 of Set 15 | sinnamary
# Processing Record 26 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 15 | zhezkazgan
# Processing Record 28 of Set 15 | gizo
# Processing Record 29 of Set 15 | mari-turek
# Processing Record 30 of Set 15 | chatham
# Processing Record 31 of Set 15 | yumen
# Processing Record 32 of Set 15 | godfrey
# Processing Record 33 of Set 15 | becej
# Processing Record 34 of Set 15 | hay river
# Processing Record 35 of Set 15 | tadine
# Processing Record 36 of Set 15 | chardara
# Processing Record 37 of Set 15 | port-gentil
# Processing Record 38 of Set 15 | presidencia roque saenz pena
# Processing Record 39 of Set 15 | khadyzhensk
# Processing Record 40 of Set 15 | camalu
# Processing Record 41 of Set 15 | stepnyak
# Processing Record 42 of Set 15 | kamina
# Processing Record 43 of Set 15 | mbini
# Processing Record 44 of Set 15 | zhangye
# Processing Record 45 of Set 15 | dharchula
# Processing Record 46 of Set 15 | pedasi
# Processing Record 47 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 15 | yerbogachen
# Processing Record 49 of Set 15 | manoel urbano
# Processing Record 50 of Set 15 | dallas
# Processing Record 1 of Set 16 | vardo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the data to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     62.01        65          97
# 1             Hami  42.8000   93.4500     79.25        11           0
# 2          Ushuaia -54.8000  -68.3000     37.06        87         100
# 3          Qaanaaq  77.4840  -69.3632     24.89        83          41
# 4    Sainte-Maxime  43.3000    6.6333     69.82        35          24
# ..             ...      ...       ...       ...       ...         ...
# 688         Pedasi   7.5333  -80.0333     78.06        84         100
# 689    Yerbogachen  61.2767  108.0108     43.09        56         100
# 690  Manoel Urbano  -8.8389  -69.2597     69.55        72          16
# 691         Dallas  32.7668  -96.7836     80.49        78           0
# 692          Vardo  70.3705   31.1107     48.18        93         100
#
#      Wind Speed Country      Current Description
# 0         13.02      AU          overcast clouds
# 1          2.82      CN                clear sky
# 2         26.46      AR  light intensity drizzle
# 3          8.66      GL         scattered clouds
# 4         30.11      FR               few clouds
# ..          ...     ...                      ...
# 688        5.79      PA          overcast clouds
# 689       12.57      RU          overcast clouds
# 690        1.72      BR               few clouds
# 691       13.80      US                clear sky
# 692       24.16      NO               light rain
#
# [693 rows x 9 columns]

# %%
# Reorder the columns
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.6500  115.3333     62.01        65          97
# 1             Hami      CN  42.8000   93.4500     79.25        11           0
# 2          Ushuaia      AR -54.8000  -68.3000     37.06        87         100
# 3          Qaanaaq      GL  77.4840  -69.3632     24.89        83          41
# 4    Sainte-Maxime      FR  43.3000    6.6333     69.82        35          24
# ..             ...     ...      ...       ...       ...       ...         ...
# 688         Pedasi      PA   7.5333  -80.0333     78.06        84         100
# 689    Yerbogachen      RU  61.2767  108.0108     43.09        56         100
# 690  Manoel Urbano      BR  -8.8389  -69.2597     69.55        72          16
# 691         Dallas      US  32.7668  -96.7836     80.49        78           0
# 692          Vardo      NO  70.3705   31.1107     48.18        93         100
#
#      Wind Speed      Current Description
# 0         13.02          overcast clouds
# 1          2.82                clear sky
# 2         26.46  light intensity drizzle
# 3          8.66         scattered clouds
# 4         30.11               few clouds
# ..          ...                      ...
# 688        5.79          overcast clouds
# 689       12.57          overcast clouds
# 690        1.72               few clouds
# 691       13.80                clear sky
# 692       24.16               light rain
#
# [693 rows x 9 columns]

# %%
# Export the city data frame into a CSV.
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
